# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import json

from tqdm.notebook import tqdm
from sklearn.metrics import roc_curve, auc, precision_recall_curve


from sklearn.metrics import (
    matthews_corrcoef,
    balanced_accuracy_score,
    f1_score,
    average_precision_score,
)
from sklearn.metrics import precision_score, recall_score

# %%
drugs_df = pd.read_csv("../processed_data/drug_fingerprints.csv", index_col=0)
drugs_df
# Out:
#                                                            MACCS_fp  \
# drug
# 5-Fluorocytosine  0000000000000000000000000000000000000110001100...
# Amikacin          0000000000000000000000000000000000000000000000...
# Amoxicillin       0000000010010000000100000000000000001000000000...
# Amphotericin B    0000000000000000000000000000000000000000000000...
# Ampicillin        0000000010010000000100000000000000001000000000...
# ...                                                             ...
# Ticarcillin       0000000010010000000100000000000000001000000000...
# Tigecycline       0000000000000000000000000010000000000000000000...
# Tobramycin        0000000000000000000000000000000000000000000000...
# Vancomycin        0000000000000000000000000000000000000000000000...
# Voriconazole      0000000010010000000000001000010011001010000101...
#
#                                                       morgan_512_fp  \
# drug
# 5-Fluorocytosine  0000000000000000000000000000000000000000000000...
# Amikacin          0100000000000100000001000000001001010000000000...
# Amoxicillin       0100010000000000001000000000000001001000000000...
# Amphotericin B    0100000000000000000001000010000001011011100000...
# Ampicillin        0100010000000000001000000000000001001000000001...
# ...                                                             ...
# Ticarcillin       0100010000000010001000000000000001001000100000...
# Tigecycline       0000000100000100000000000000010001001100011001...
# Tobramycin        0000000000010000000001000000000000010000000000...
# Vancomycin        0101000000111000000010000000000001001001000010...
# Voriconazole      0010010000000010000000100000000111000001100000...
#
#                                                      morgan_1024_fp  \
# drug
# 5-Fluorocytosine  0000000000000000000000000000000000000000000000...
# Amikacin          0100000000000100000000000000001000010000000000...
# Amoxicillin       0100010000000000001000000000000001001000000000...
# Amphotericin B    0100000000000000000000000010000001011000100000...
# Ampicillin        0100010000000000001000000000000001001000000000...
# ...                                                             ...
# Ticarcillin       0100010000000010001000000000000001001000000000...
# Tigecycline       0000000000000000000000000000000001001100010000...
# Tobramycin        0000000000010000000000000000000000010000000000...
# Vancomycin        0101000000110000000000000000000001001000000010...
# Voriconazole      0000010000000010000000000000000001000001000000...
#
#                                                          pubchem_fp
# drug
# 5-Fluorocytosine  1101110001100000000110001100100001000000000000...
# Amikacin          1101110001111100000111101110111100000000000000...
# Amoxicillin       1101110001111000000111101100111000000000000100...
# Amphotericin B    1101110001111100000111111000111110000000000000...
# Ampicillin        1101110001111000000111101100111000000000000100...
# ...                                                             ...
# Ticarcillin       1101110001111000000111001100111000000000000110...
# Tigecycline       1101110001111100000111101110111100000000000000...
# Tobramycin        1101110001111100000111101110111100000000000000...
# Vancomycin        1101110001111100000111111111111110000000000000...
# Voriconazole      1101110001111000000111101111111100000000100111...
#
# [65 rows x 4 columns]

# %%
long_table = pd.read_csv("../processed_data/DRIAMS_combined_long_table.csv")
long_table = long_table[long_table["drug"].isin(drugs_df.index)]

long_table
# Out:
#                            species                                  sample_id  \
# 0       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# 1       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# 2       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# 3       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# 4       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# ...                            ...                                        ...
# 652766       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
# 652767       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
# 652768       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
# 652769       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
# 652770       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
#
#                  drug  response dataset
# 0           Meropenem         1       A
# 1       Ciprofloxacin         1       A
# 2            Cefepime         1       A
# 3       Cotrimoxazole         0       A
# 4            Imipenem         1       A
# ...               ...       ...     ...
# 652766      Linezolid         0       D
# 652767     Rifampicin         0       D
# 652768   Tetracycline         0       D
# 652769    Tigecycline         0       D
# 652770     Vancomycin         0       D
#
# [652608 rows x 5 columns]

# %%
# folder_template = "outputs/ResAMR_DrugZeroShot/ZS_noCNN_emb512_DRIAMS-{}_drugs_zero_shot_sp0"
drug_zs_results = []
threshold = 0.5
folder = "outputs/ResAMR_DrugZeroShot/ZS_noCNN_emb512_results"

for fname in tqdm(os.listdir(folder)):
    if not fname.startswith("DRIAMS"):
        continue
        
    drug_name = fname.split("_")[1]
    dset = fname.split("_")[0].split("-")[1]
    
    dataset_long_table = long_table[long_table["dataset"]==dset]
    
    test_set = pd.read_csv(os.path.join(folder, fname))
    
    trainval_data = dataset_long_table[~dataset_long_table[["sample_id", "drug"]].apply(tuple,1).isin(test_set_comb)]
    
    species_majority_response = {}
    for sp in trainval_data["species"].unique():
        avg_species_response = trainval_data[trainval_data["species"]==sp]["response"].mean()
        species_majority_response[sp] = 0 if avg_species_response<0.5 else 1
        
        
    # break
    response_classes = test_set["response"]
    predicted_classes = []
    for i, row in test_set.iterrows():
        predicted_classes.append(species_majority_response[row.species])
    
#     response_classes = test_set["response"].values
# #     predictions = test_set["Predictions"].values
    
#     predicted_classes = (predictions>=threshold).astype(int)
    
    metrics =  {
            "mcc": matthews_corrcoef(response_classes, predicted_classes),
            "balanced_accuracy": balanced_accuracy_score(
                response_classes, predicted_classes
            ),
            "f1": f1_score(response_classes, predicted_classes, zero_division=0),
            "AUPRC": -1,
            "precision": precision_score(
                response_classes, predicted_classes, zero_division=0
            ),
            "recall": recall_score(
                response_classes, predicted_classes, zero_division=0
            ),
        }

    
    metrics["dataset"] = dset
    metrics["drug"]=drug_name
    drug_zs_results.append(metrics)




drug_zs_results = pd.DataFrame(drug_zs_results)
# drug_zs_results.columns = ["dataset", "drug", "test_AUPRC", "n_test_samples", "n_resistant_test_samples"]
drug_zs_results = drug_zs_results.drop("drug", axis=1)

drug_zs_results
# Out:
#   0%|          | 0/163 [00:00<?, ?it/s]
# /home/gvisona/miniconda3/envs/ml_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:2006: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# /home/gvisona/miniconda3/envs/ml_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:2006: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# /home/gvisona/miniconda3/envs/ml_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:2006: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# /home/gvisona/miniconda3/envs/ml_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:2006: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
#           mcc  balanced_accuracy        f1  AUPRC  precision    recall dataset
# 0    0.389526           0.576923  0.266667     -1   1.000000  0.153846       B
# 1    0.000000           0.500000  0.000000     -1   0.000000  0.000000       D
# 2   -0.018399           0.497774  0.000000     -1   0.000000  0.000000       B
# 3    0.057497           0.503501  0.013908     -1   1.000000  0.007003       B
# 4    0.000000           0.500000  0.000000     -1   0.000000  0.000000       B
# ..        ...                ...       ...    ...        ...       ...     ...
# 158  0.000000           0.500000  0.000000     -1   0.000000  0.000000       D
# 159  0.026597           0.504817  0.055322     -1   0.808571  0.028641       A
# 160  0.000000           1.000000  0.000000     -1   0.000000  0.000000       D
# 161  0.048850           0.501988  0.007921     -1   1.000000  0.003976       C
# 162 -0.001329           0.499226  0.000000     -1   0.000000  0.000000       A
#
# [163 rows x 7 columns]

# %%
species_majority_response
# Out:
# {'Staphylococcus epidermidis': 0,
#  'Enterococcus faecalis': 0,
#  'Enterococcus faecium': 0,
#  'Klebsiella oxytoca': 0,
#  'Pseudomonas aeruginosa': 0,
#  'Streptococcus oralis': 0,
#  'Streptococcus equinus': 0,
#  'Escherichia coli': 0,
#  'Proteus mirabilis': 0,
#  'Enterobacter asburiae': 0,
#  'Streptococcus agalactiae': 0,
#  'Enterobacter ludwigii': 0,
#  'Staphylococcus hominis': 0,
#  'Lactobacillus rhamnosus': 0,
#  'Enterobacter cloacae': 0,
#  'Serratia marcescens': 0,
#  'Klebsiella pneumoniae': 0,
#  'Staphylococcus saprophyticus': 0,
#  'Stenotrophomonas maltophilia': 0,
#  'Staphylococcus aureus': 0,
#  'Candida glabrata': 0,
#  'Citrobacter koseri': 0,
#  'Enterococcus dispar': 0,
#  'Burkholderia ambifaria': 0,
#  'Staphylococcus caprae': 0,
#  'Campylobacter jejuni': 0,
#  'Staphylococcus capitis': 0,
#  'Neisseria gonorrhoeae': 0,
#  'Haemophilus parainfluenzae': 0,
#  'Propionibacterium acnes': 0,
#  'Haemophilus influenzae': 0,
#  'Aerococcus sanguinicola': 0,
#  'Staphylococcus pettenkoferi': 0,
#  'Clostridium difficile': 0,
#  'Morganella morganii': 0,
#  'Providencia rettgeri': 0,
#  'Eikenella corrodens': 0,
#  'Candida albicans': 0,
#  'Corynebacterium striatum': 0,
#  'Streptococcus pneumoniae': 0,
#  'Corynebacterium simulans': 0,
#  'Micrococcus luteus': 0,
#  'MIX!Haemophilus influenzae': 0,
#  'Corynebacterium jeikeium': 1,
#  'Enterobacter aerogenes': 0,
#  'Pseudomonas sp': 0,
#  'Aeromonas ichthiosmia': 0,
#  'Aeromonas veronii': 0,
#  'Citrobacter freundii': 0,
#  'Staphylococcus warneri': 0,
#  'Aerococcus urinae': 0,
#  'Streptococcus dysgalactiae': 0,
#  'Streptococcus parasanguinis': 0,
#  'Staphylococcus haemolyticus': 0,
#  'Klebsiella variicola': 0,
#  'MIX!Klebsiella pneumoniae': 0,
#  'Enterobacter kobei': 0,
#  'MIX!Enterobacter cloacae': 0,
#  'MIX!Serratia marcescens': 0,
#  'Staphylococcus lugdunensis': 0,
#  'Corynebacterium kroppenstedtii': 0,
#  'Proteus vulgaris': 0,
#  'Hafnia alvei': 0,
#  'MIX!Staphylococcus lugdunensis': 0,
#  'Citrobacter braakii': 0,
#  'MIX!Stenotrophomonas maltophilia': 0,
#  'MIX!Haemophilus parainfluenzae': 1,
#  'Staphylococcus pasteuri': 0,
#  'Actinomyces odontolyticus': 0,
#  'Streptococcus intermedius': 0,
#  'Streptococcus mitis': 0,
#  'Turicella otitidis': 0,
#  'MIX!Proteus mirabilis': 0,
#  'MIX!Citrobacter freundii': 0,
#  'Corynebacterium tuberculostearicum': 1,
#  'Streptococcus salivarius': 0,
#  'Burkholderia anthina': 0,
#  'Burkholderia cenocepacia': 0,
#  'Candida albicans_(africana)': 0,
#  'MIX!Enterobacter asburiae': 0,
#  'Streptococcus pyogenes': 0,
#  'Corynebacterium amycolatum': 1,
#  'MIX!Corynebacterium tuberculostearicum': 0,
#  'MIX!Staphylococcus aureus': 0,
#  'Enterococcus avium': 0,
#  'Bacteroides thetaiotaomicron': 0,
#  'Acinetobacter parvus': 0,
#  'Corynebacterium glucuronolyticum': 0,
#  'MIX!Staphylococcus epidermidis': 0,
#  'Serratia liquefaciens': 0,
#  'MIX!Neisseria gonorrhoeae': 0,
#  'Corynebacterium coyleae': 0,
#  'Acinetobacter ursingii': 0,
#  'MIX!Candida albicans': 0,
#  'Serratia ureilytica': 0,
#  'Acinetobacter baumannii': 0,
#  'Candida parapsilosis': 0,
#  'Corynebacterium lipophile_group_F1': 0,
#  'Serratia grimesii': 0,
#  'Rothia dentocariosa': 0,
#  'Staphylococcus saccharolyticus': 0,
#  'Streptococcus pseudopneumoniae': 0,
#  'MIX!Haemophilus haemolyticus': 0,
#  'MIX!Aggregatibacter aphrophilus': 0,
#  'Candida dubliniensis': 0,
#  'Burkholderia vietnamiensis': 0,
#  'MIX!Haemophilus parahaemolyticus': 0,
#  'Parvimonas micra': 0,
#  'MIX!Streptococcus peroris': 0,
#  'Saccharomyces cerevisiae': 0,
#  'Actinotignum schaalii': 0,
#  'Streptococcus gallolyticus': 0,
#  'Propionibacterium avidum': 0,
#  'Pantoea agglomerans': 0,
#  'Delftia acidovorans': 0,
#  'Pseudomonas graminis': 0,
#  'Pseudomonas stutzeri': 0,
#  'Salmonella spp': 0,
#  'Bilophila wadsworthia': 0,
#  'Fusobacterium sp': 0,
#  'Bacteroides fragilis': 0,
#  'Clostridium ramosum': 0,
#  'Acinetobacter junii': 0,
#  'Achromobacter xylosoxidans': 1,
#  'Bacteroides uniformis': 0,
#  'MIX!Achromobacter insolitus': 1,
#  'Staphylococcus intermedius': 0,
#  'Dialister pneumosintes': 0,
#  'MIX!Enterococcus avium': 0,
#  'Acinetobacter pittii': 0,
#  'MIX!Acinetobacter pittii': 0,
#  'Staphylococcus cohnii': 0,
#  'MIX!Gemella morbillorum': 0,
#  'Aggregatibacter aphrophilus': 0,
#  'Actinotignum sanguinis': 0,
#  'Streptococcus anginosus': 0,
#  'Haemophilus haemolyticus': 0,
#  'Enterococcus raffinosus': 0,
#  'Yersinia enterocolitica': 0,
#  'Actinomyces turicensis': 0,
#  'Acinetobacter bereziniae': 0,
#  'Peptoniphilus coxii': 0,
#  'Porphyromonas uenonis': 0,
#  'MIX!Streptococcus dysgalactiae': 0,
#  'Peptoniphilus harei': 0,
#  'Anaerococcus vaginalis': 0,
#  'Prevotella buccalis': 1,
#  'Finegoldia magna': 0,
#  'MIX!Escherichia coli': 0,
#  'Dermabacter hominis': 1,
#  'Actinomyces neuii': 0,
#  'Pseudomonas nitroreducens': 0,
#  'MIX!Staphylococcus hominis': 0,
#  'Granulicatella adiacens': 0,
#  'Streptococcus cristatus': 0,
#  'Actinomyces oris': 0,
#  'Prevotella timonensis': 1,
#  'Providencia stuartii': 0,
#  'MIX!Pseudomonas aeruginosa': 0,
#  'Trueperella bernardiae': 0,
#  'Eggerthella lenta': 0,
#  'MIX!Bacillus cereus': 0,
#  'Bacillus thuringiensis': 0,
#  'Bacillus cereus': 0,
#  'Bacillus mycoides': 0,
#  'Corynebacterium pyruviciproducens': 1,
#  'Corynebacterium macginleyi': 0,
#  'Staphylococcus xylosus': 0,
#  'Streptococcus constellatus': 0,
#  'Aeromonas encheleia': 0,
#  'Streptococcus lutetiensis': 0,
#  'Staphylococcus auricularis': 0,
#  'Propionibacterium granulosum': 0,
#  'Salmonella anatum': 0,
#  'Corynebacterium aurimucosum': 0,
#  'MIX!Chryseobacterium gleum': 0,
#  'Staphylococcus simulans': 0,
#  'Campylobacter coli': 1,
#  'Escherichia hermannii': 0,
#  'Staphylococcus piscifermentans': 0,
#  'Lactobacillus salivarius': 0,
#  'Sphingomonas paucimobilis': 0,
#  'Acinetobacter nosocomialis': 0,
#  'Acinetobacter haemolyticus': 0,
#  'Kosakonia cowanii': 0,
#  'Peptoniphilus tyrrelliae': 1,
#  'Candida bracarensis': 0,
#  'MIX!Achromobacter xylosoxidans': 1,
#  'Anaerococcus murdochii': 0,
#  'Propionibacterium sp': 0,
#  'Prevotella denticola': 0,
#  'MIX!Streptococcus pyogenes': 0,
#  'Candida tropicalis': 0,
#  'Leuconostoc citreum': 0,
#  'Aerococcus viridans': 0,
#  'Haemophilus parahaemolyticus': 0,
#  'Streptococcus canis': 0,
#  'Sphingomonas koreensis': 1,
#  'Proteus hauseri': 0,
#  'MIX!Enterococcus faecium': 0,
#  'Corynebacterium afermentans': 0,
#  'Arcobacter butzleri': 0,
#  'MIX!Arcobacter butzleri': 1,
#  'MIX!Streptococcus mitis': 0,
#  'MIX!Acinetobacter baumannii': 0,
#  'Staphylococcus schleiferi': 0,
#  'Streptococcus sanguinis': 0,
#  'Streptococcus peroris': 0,
#  'MIX!Bacteroides vulgatus': 0,
#  'Pseudomonas brenneri': 0,
#  'Corynebacterium urealyticum': 1,
#  'Paenibacillus jamilae': 1,
#  'Providencia alcalifaciens': 0,
#  'Pseudomonas citronellolis': 0,
#  'MIX!Pseudomonas citronellolis': 0,
#  'MIX!Pasteurella bettyae': 0,
#  'Staphylococcus pseudintermedius': 0,
#  'Kocuria sp': 0,
#  'Chryseobacterium sp': 0,
#  'Lactobacillus delbrueckii': 1,
#  'Kluyvera ascorbata': 0,
#  'Streptococcus gordonii': 0,
#  'Raoultella ornithinolytica': 0,
#  'MIX!Klebsiella oxytoca': 0,
#  'Bacillus firmus': 1,
#  'Candida kefyr': 0,
#  'Acinetobacter calcoaceticus': 0,
#  'Erwinia persicina': 0,
#  'MIX!Campylobacter jejuni': 0,
#  'Streptococcus salivarius_ssp_thermophilus': 0,
#  'MIX!Aeromonas caviae': 0,
#  'Streptococcus vestibularis': 0,
#  'MIX!Eggerthella lenta': 0,
#  'MIX!Staphylococcus cohnii': 0,
#  'Pandoraea sputorum': 1,
#  'MIX!Pandoraea pulmonicola': 1,
#  'MIX!Aeromonas eucrenophila': 0,
#  'MIX!Bacillus altitudinis': 0,
#  'MIX!Bacillus pumilus': 0,
#  'Pseudomonas monteilii': 0,
#  'Clostridium subterminale': 0,
#  'Campylobacter concisus': 1,
#  'Facklamia hominis': 1,
#  'Parabacteroides distasonis': 0,
#  'Rothia mucilaginosa': 0,
#  'Citrobacter murliniae': 0,
#  'MIX!Streptococcus parasanguinis': 0,
#  'Prevotella veroralis': 0,
#  'Ochrobactrum anthropi': 0,
#  'Corynebacterium pseudodiphtheriticum': 0,
#  'Citrobacter amalonaticus': 0,
#  'MIX!Streptococcus pneumoniae': 0,
#  'Lactobacillus fermentum': 1,
#  'Pseudomonas putida_Group': 0,
#  'Capnocytophaga sp': 0,
#  'MIX!Aeromonas enteropelogenes': 0,
#  'Aggregatibacter actinomycetemcomitans': 0,
#  'Bacillus pumilus': 0,
#  'Anaerococcus sp': 0,
#  'Enterococcus hirae': 0,
#  'Dermacoccus nishinomiyaensis': 0,
#  'Streptococcus infantis': 0,
#  'Fusobacterium sp[2]': 0,
#  'Lactobacillus paracasei': 0,
#  'Actinomyces meyeri': 0,
#  'Brevundimonas diminuta': 1,
#  'Alcaligenes faecalis': 0,
#  'Corynebacterium singulare': 0,
#  'Rhizobium radiobacter': 0,
#  'Pseudomonas koreensis': 0,
#  'Achromobacter insolitus': 0,
#  'MIX!Streptococcus salivarius_ssp_thermophilus': 0,
#  'Rothia aeria': 0,
#  'Pasteurella multocida': 0,
#  'MIX!Aeromonas veronii': 0,
#  'Fusobacterium necrophorum': 0,
#  'Aeromonas caviae': 0,
#  'Bacteroides ovatus': 0,
#  'Capnocytophaga sputigena': 0,
#  'MIX!Enterococcus faecalis': 0,
#  'Nocardia blacklockiae': 1,
#  'Fusobacterium nucleatum': 0,
#  'MIX!Pasteurella multocida': 0,
#  'MIX!Enterobacter kobei': 0,
#  'MIX!Streptococcus agalactiae': 0,
#  'Ochrobactrum intermedium': 0,
#  'Pseudomonas putida': 0,
#  'Enterococcus casseliflavus': 0,
#  'Chryseobacterium indologenes': 1,
#  'Enterococcus durans': 0,
#  'Chryseobacterium gleum': 0,
#  'Gemella sanguinis': 0,
#  'MIX!Acinetobacter baylyi': 0,
#  'Pseudomonas synxantha': 0,
#  'MIX!Corynebacterium minutissimum': 0,
#  'MIX!Pasteurella canis': 0,
#  'Butyricimonas virosa': 0,
#  'MIX!Aeromonas hydrophila': 0,
#  'Neisseria meningitidis': 0,
#  'Microbacterium aurum': 0,
#  'Bifidobacterium dentium': 0,
#  'MIX!Aerococcus sanguinicola': 1,
#  'Bordetella trematum': 0,
#  'Gemella haemolysans': 0,
#  'Aggregatibacter segnis': 0,
#  'Citrobacter farmeri': 0,
#  'MIX!Streptococcus pseudopneumoniae': 0,
#  'MIX!Proteus vulgaris': 0,
#  'Haemophilus pittmaniae': 0,
#  'Rahnella aquatilis': 0,
#  'Gardnerella vaginalis': 1,
#  'MIX!Haemophilus pittmaniae': 1,
#  'Corynebacterium propinquum': 0,
#  'Gemella morbillorum': 0,
#  'MIX!Finegoldia magna': 0,
#  'Leclercia adecarboxylata': 0,
#  'Enterobacter hormaechei': 0,
#  'MIX!Lelliottia amnigena': 0,
#  'Staphylococcus sp[1]': 0,
#  'Neisseria subflava': 1,
#  'MIX!Brevibacterium celere': 0,
#  'Aspergillus terreus': 0,
#  'MIX!Bacillus mycoides': 0,
#  'MIX!Paenibacillus jamilae': 1,
#  'Slackia exigua': 0,
#  'Comamonas kerstersii': 0,
#  'Pseudomonas fluorescens': 0,
#  'MIX!Staphylococcus saprophyticus': 0,
#  'Bacillus weihenstephanensis': 1,
#  'Serratia ficaria': 0,
#  'MIX!Staphylococcus gallinarum': 0,
#  'Clostridium perfringens': 0,
#  'MIX!Pseudomonas mosselii': 0,
#  'Alloscardovia omnicolens': 0,
#  'Vibrio alginolyticus': 0,
#  'Pseudomonas oryzihabitans': 0,
#  'Bacillus altitudinis': 0,
#  'Citrobacter sedlakii': 0,
#  'Veillonella parvula': 0,
#  'Haemophilus sputorum': 0,
#  'MIX!Streptococcus canis': 0,
#  'Prevotella intermedia': 0,
#  'MIX!Morganella morganii': 0,
#  'Acinetobacter radioresistens': 0,
#  'Streptococcus sinensis': 0,
#  'Ruminococcus gnavus': 0,
#  'MIX!Streptococcus intermedius': 0,
#  'MIX!Pseudomonas fluorescens': 0,
#  'Bacillus circulans': 0,
#  'Corynebacterium ulcerans': 0,
#  'Staphylococcus succinus': 0,
#  'MIX!Corynebacterium ulcerans': 0,
#  'MIX!Acinetobacter junii': 0,
#  'Brevibacterium celere': 0,
#  'Corynebacterium sp': 0,
#  'MIX!Corynebacterium aurimucosum': 1,
#  'Aeromonas hydrophila': 0,
#  'MIX!Corynebacterium striatum': 1,
#  'MIX!Peptoniphilus harei': 1,
#  'Candida krusei': 0,
#  'MIX!Staphylococcus haemolyticus': 1,
#  'Clostridium paraputrificum': 0,
#  'MIX!Veillonella parvula': 0,
#  'MIX!Pseudomonas protegens': 0,
#  'MIX!Staphylococcus sp[1]': 0,
#  'MIX!Pseudomonas sp': 0,
#  'Bacillus vallismortis': 0,
#  'Enterobacter cancerogenus': 0,
#  'Bifidobacterium pseudocatenulatum': 0,
#  'Candida guilliermondii': 0,
#  'MIX!Acinetobacter lwoffii': 0,
#  'MIX!Acinetobacter johnsonii': 0,
#  'Bacteroides vulgatus': 0,
#  'Burkholderia multivorans': 1,
#  'MIX!Enterococcus gallinarum': 0,
#  'Abiotrophia defectiva': 0,
#  'MIX!Klebsiella variicola': 0,
#  'Staphylococcus condimenti': 0,
#  'Serratia proteamaculans': 0,
#  'MIX!Acinetobacter tjernbergiae': 0,
#  'Paenibacillus illinoisensis': 1,
#  'Paenibacillus amylolyticus': 1,
#  'Acinetobacter johnsonii': 0,
#  'Clostridium sporogenes': 0,
#  'Lactobacillus gasseri': 0,
#  'Pantoea septica': 0,
#  'Bergeyella zoohelcum': 0,
#  'MIX!Lactobacillus paracasei': 0,
#  'Bacteroides faecis': 0,
#  'Enterococcus gallinarum': 0,
#  'Acinetobacter lwoffii': 0,
#  'Corynebacterium imitans': 1,
#  'MIX!Campylobacter coli': 1,
#  'Serratia rubidaea': 0,
#  'Clostridium baratii': 0,
#  'Arcanobacterium haemolyticum': 0,
#  'Aspergillus fumigatus': 0,
#  'Achromobacter spanius': 0,
#  'Lactococcus lactis': 0,
#  'MIX!Achromobacter piechaudii': 0,
#  'MIX!Enterobacter ludwigii': 0,
#  'MIX!Acinetobacter haemolyticus': 0,
#  'MIX!Achromobacter denitrificans': 0,
#  'Clostridium clostridioforme': 0,
#  'Brevibacterium paucivorans': 0,
#  'Corynebacterium confusum': 0,
#  'Citrobacter youngae': 0,
#  'MIX!Citrobacter sedlakii': 0,
#  'MIX!Pseudomonas monteilii': 0,
#  'Bacillus subtilis': 0,
#  'Candida nivariensis': 0,
#  'Listeria monocytogenes': 0,
#  'Kocuria rhizophila': 0,
#  'Burkholderia gladioli': 0,
#  'MIX!Burkholderia gladioli': 0,
#  'Campylobacter fetus': 0,
#  'MIX!Staphylococcus pseudintermedius': 0,
#  'Lactococcus garvieae': 0,
#  'Serratia fonticola': 0,
#  'Pseudomonas plecoglossicida': 0,
#  'MIX!Pseudomonas sp[2]': 0,
#  'MIX!Pseudomonas plecoglossicida': 0,
#  'MIX!Lactobacillus rhamnosus': 1,
#  'Neisseria elongata': 0,
#  'Corynebacterium mucifaciens': 0,
#  'MIX!Enterococcus casseliflavus': 0,
#  'MIX!Enterococcus mundtii': 0,
#  'MIX!Staphylococcus capitis': 0,
#  'Arthrobacter cumminsii': 0,
#  'MIX!Candida inconspicua': 0,
#  'Bacteroides caccae': 0,
#  'MIX!Candida tropicalis': 0,
#  'Pantoea dispersa': 0,
#  'Pediococcus pentosaceus': 1,
#  'MIX!Streptococcus lutetiensis': 0,
#  'Brevibacterium ravenspurgense': 0,
#  'MIX!Brevibacterium ravenspurgense': 0,
#  'Bordetella petrii': 1,
#  'MIX!Neisseria meningitidis': 0,
#  'Bacillus endophyticus': 0,
#  'MIX!Aeromonas ichthiosmia': 0,
#  'MIX!Citrobacter koseri': 0,
#  'Candida inconspicua': 0,
#  'MIX!Pseudomonas nitroreducens': 0,
#  'Bacillus mojavensis': 0,
#  'Campylobacter upsaliensis': 0,
#  'MIX!Serratia liquefaciens': 0,
#  'Actinobacillus ureae': 0,
#  'MIX!Streptococcus vestibularis': 0,
#  'Pseudomonas fulva': 0,
#  'MIX!Aeromonas media': 0,
#  'MIX!Aeromonas bestiarum': 0,
#  'MIX!Fusobacterium sp': 0,
#  'Peptostreptococcus anaerobius': 0,
#  'Peptoniphilus olsenii': 0,
#  'MIX!Acinetobacter calcoaceticus': 0,
#  'Pasteurella dagmatis': 0,
#  'Bordetella bronchiseptica': 1,
#  'Brevibacterium casei': 0,
#  'Proteus penneri': 0,
#  'Streptococcus mutans': 0,
#  'Burkholderia cepacia_Group': 0,
#  'Plesiomonas shigelloides': 0,
#  'Corynebacterium diphtheriae': 0,
#  'MIX!Corynebacterium macginleyi': 0,
#  'Clostridium symbiosum': 1,
#  'Kingella kingae': 0,
#  'Kingella oralis': 0,
#  'MIX!Salmonella sp': 0,
#  'MIX!Pandoraea sp[2]': 1,
#  'Staphylococcus gallinarum': 0,
#  'Bifidobacterium longum': 0,
#  'Paenibacillus timonensis': 0,
#  'MIX!Aggregatibacter segnis': 0,
#  'Anaerococcus hydrogenalis': 1,
#  'MIX!Staphylococcus pettenkoferi': 0,
#  'Pseudomonas flavescens': 0,
#  'Trichosporon mycotoxinivorans': 1,
#  'MIX!Achromobacter spanius': 0,
#  'Aeromonas salmonicida': 0,
#  'Corynebacterium mastitidis': 0,
#  'MIX!Delftia acidovorans': 0,
#  'Pseudomonas alcaligenes': 0,
#  'MIX!Staphylococcus auricularis': 0,
#  'Candida lusitaniae': 0,
#  'Burkholderia pyrrocinia': 0,
#  'Pseudomonas luteola': 0,
#  'MIX!Pseudomonas synxantha': 0,
#  'Pseudomonas libanensis': 0,
#  'Corynebacterium sundsvallense': 0,
#  'Pseudomonas rhodesiae': 1,
#  'Pseudomonas mosselii': 0,
#  'Salmonella newington': 0,
#  'Helcococcus kunzii': 0,
#  'Salmonella sp': 0,
#  'Enterococcus pseudoavium': 0,
#  'MIX!Burkholderia ambifaria': 0,
#  'Burkholderia latens': 0,
#  'Aerococcus christensenii': 1,
#  'Actinomyces funkei': 0,
#  'MIX!Burkholderia cepacia_Group': 0,
#  'Sphingomonas sanguinis': 0,
#  'Paenibacillus macerans': 1,
#  'Clostridium innocuum': 1,
#  'Sphingobacterium spiritivorum': 0,
#  'MIX!Helcococcus kunzii': 0,
#  'Nocardia veterana': 0,
#  'Corynebacterium accolens': 1,
#  'MIX!Fusobacterium nucleatum': 0,
#  'Corynebacterium bovis': 0,
#  'MIX!Enterobacter aerogenes': 0,
#  'MIX!Candida dubliniensis': 0,
#  'Candida pararugosa': 0,
#  'Trueperella pyogenes': 0,
#  'MIX!Citrobacter braakii': 0,
#  'Oligella urethralis': 0,
#  'MIX!Enterococcus hirae': 0,
#  'Providencia rustigianii': 0,
#  'Moraxella sp': 0,
#  'Kluyvera cryocrescens': 0,
#  'Staphylococcus delphini': 0,
#  'MIX!Pseudomonas flavescens': 0,
#  'Yersinia intermedia': 0,
#  'Corynebacterium resistens': 0,
#  'MIX!Burkholderia cepacia': 0,
#  'MIX!Fusobacterium periodonticum': 0,
#  'Pasteurella bettyae': 0,
#  'Pseudomonas otitidis': 0,
#  'Peptoniphilus sp': 0,
#  'Campylobacter rectus': 0,
#  'MIX!Acinetobacter ursingii': 0,
#  'Campylobacter ureolyticus': 0,
#  'Streptococcus massiliensis': 0,
#  'MIX!Pseudomonas putida_Group': 0,
#  'Acidovorax temperans': 0,
#  'Nocardia sp': 0,
#  'Lysinibacillus fusiformis': 1,
#  'MIX!Salmonella spp': 0,
#  'Pseudomonas mendocina': 0,
#  'Enterococcus gilvus': 0,
#  'Pandoraea pnomenusa': 0,
#  'MIX!Pandoraea pnomenusa': 0,
#  'Sphingomonas desiccabilis': 0,
#  'Aeromonas media': 0,
#  'Brevibacillus brevis': 1,
#  'MIX!Prevotella melaninogenica': 0,
#  'MIX!Acinetobacter bereziniae': 0,
#  'Burkholderia cepacia': 0,
#  'MIX!Bacillus weihenstephanensis': 0,
#  'Prevotella disiens': 0,
#  'Eubacterium sp[2]': 1,
#  'Atopobium parvulum': 0,
#  'MIX!Parvimonas micra': 0,
#  'Fusobacterium gonidiaformans': 0,
#  'Chryseobacterium joostei': 0,
#  'Eubacterium limosum': 1,
#  'Fusobacterium periodonticum': 0,
#  'MIX!Pseudomonas putida': 0,
#  'Candida orthopsilosis': 0,
#  'Clostridium glycolicum': 0,
#  'MIX!Acinetobacter parvus': 1,
#  'Bacillus licheniformis': 1,
#  'MIX!Clostridium glycolicum': 0,
#  'MIX!Pasteurella dagmatis': 0}

# %%
drug_zs_results.groupby("dataset").std()
# Out:
#               mcc  balanced_accuracy        f1  AUPRC  precision    recall
# dataset
# A        0.126789           0.075894  0.111406    0.0   0.396952  0.080664
# B        0.094867           0.120369  0.057827    0.0   0.489296  0.032855
# C        0.277865           0.240346  0.306975    0.0   0.428847  0.326633
# D        0.000000           0.154731  0.000000    0.0   0.000000  0.000000

# %%
test_set_comb = set(map(tuple, test_set[["sample_id", "drug"]].values.tolist()))

# %%
dataset_long_table[~dataset_long_table[["sample_id", "drug"]].apply(tuple,1).isin(test_set_comb)]
# Out:
#                       species                             sample_id  \
# 474238  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# 474239  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# 474240  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# 474241  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# 474242  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# ...                       ...                                   ...
# 506609  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
# 506611  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
# 506612  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
# 506613  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
# 506614  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
#
#                 drug  response dataset
# 474238      Amikacin         0       B
# 474239    Ampicillin         1       B
# 474240      Cefepime         0       B
# 474241     Cefoxitin         0       B
# 474242   Ceftazidime         0       B
# ...              ...       ...     ...
# 506609     Oxacillin         0       B
# 506611   Teicoplanin         0       B
# 506612  Tetracycline         0       B
# 506613   Tigecycline         0       B
# 506614    Vancomycin         0       B
#
# [31575 rows x 5 columns]

# %%
dataset_long_table
# Out:
#                       species                             sample_id  \
# 474238  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# 474239  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# 474240  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# 474241  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# 474242  Klebsiella pneumoniae  ca568529-351a-43af-8cec-7175488f66ea
# ...                       ...                                   ...
# 506610  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
# 506611  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
# 506612  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
# 506613  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
# 506614  Staphylococcus aureus  57043b13-3ba8-4f30-83ac-2416c23cec3a
#
#                 drug  response dataset
# 474238      Amikacin         0       B
# 474239    Ampicillin         1       B
# 474240      Cefepime         0       B
# 474241     Cefoxitin         0       B
# 474242   Ceftazidime         0       B
# ...              ...       ...     ...
# 506610    Rifampicin         0       B
# 506611   Teicoplanin         0       B
# 506612  Tetracycline         0       B
# 506613   Tigecycline         0       B
# 506614    Vancomycin         0       B
#
# [32377 rows x 5 columns]

# %%
32377-31575
# Out:
# 802
