# %%
import pandas as pd
import numpy as np
import os
from os.path import join, exists
import json
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.metrics import roc_curve, auc, precision_recall_curve


from sklearn.metrics import (
    matthews_corrcoef,
    balanced_accuracy_score,
    f1_score,
    average_precision_score,
)
from sklearn.metrics import precision_score, recall_score

# %%
# template = "embdim512_DRIAMS-{}_{}_sp{}_results"
template = "rand_DRIAMS-B_{}_metrics"

dataset = "B"
splits = ["random", "partitioned"]

# %%
metrics_df = []

# for dset in datasets:
for sp in splits:
    for i in range(10):
        try:
            with open(join("outputs/RandomClassifier", template.format(sp), f"test_metrics_{i}.json"), "r") as f:
                met = json.load(f)
            met["dataset"] = dataset
            met["split"] = sp
            met["seed"]=i
            # met["species_embedding_dim"]=dim
            metrics_df.append(met)
        except:
            continue
    
metrics_df = pd.DataFrame(metrics_df)
metrics_df = metrics_df.drop(["seed"], axis=1)
metrics_df
# Out:
#          mcc  balanced_accuracy        f1  AUPRC  precision    recall dataset  \
# 0   0.000750           0.500504  0.249185     -1   0.166149  0.498138       B
# 1   0.007405           0.504977  0.253247     -1   0.168623  0.508380       B
# 2   0.003111           0.502091  0.250755     -1   0.167028  0.502793       B
# 3  -0.006570           0.495584  0.245541     -1   0.163429  0.493482       B
# 4  -0.020199           0.486429  0.235990     -1   0.158162  0.464618       B
# 5  -0.011289           0.492412  0.242495     -1   0.161651  0.485102       B
# 6  -0.003895           0.497383  0.248405     -1   0.164454  0.507449       B
# 7   0.001203           0.500808  0.250517     -1   0.166311  0.507449       B
# 8  -0.012813           0.491389  0.241620     -1   0.161080  0.483240       B
# 9   0.005870           0.503945  0.252038     -1   0.168065  0.503724       B
# 10 -0.000420           0.499739  0.288592     -1   0.202458  0.502287       B
# 11  0.020721           0.512766  0.305166     -1   0.216325  0.517831       B
# 12 -0.009734           0.493839  0.274293     -1   0.189560  0.496006       B
# 13  0.018022           0.511293  0.294209     -1   0.205837  0.515552       B
# 14 -0.009350           0.494098  0.275050     -1   0.191049  0.490880       B
# 15 -0.004780           0.497029  0.286341     -1   0.201171  0.496578       B
# 16 -0.002326           0.498570  0.293130     -1   0.207856  0.497041       B
# 17 -0.000106           0.499935  0.294810     -1   0.209223  0.498893       B
# 18  0.007225           0.504562  0.284957     -1   0.197429  0.511905       B
# 19  0.000892           0.500556  0.288466     -1   0.201900  0.504981       B
#
#           split
# 0        random
# 1        random
# 2        random
# 3        random
# 4        random
# 5        random
# 6        random
# 7        random
# 8        random
# 9        random
# 10  partitioned
# 11  partitioned
# 12  partitioned
# 13  partitioned
# 14  partitioned
# 15  partitioned
# 16  partitioned
# 17  partitioned
# 18  partitioned
# 19  partitioned

# %%
mean_df = metrics_df.groupby(["split", "dataset"]).mean()
mean_df.columns = [c+"_average" for c in mean_df.columns]
std_df = metrics_df.groupby(["split", "dataset"]).std()
std_df.columns = [c+"_std" for c in std_df.columns]
std_df
joined_df = pd.merge(mean_df, std_df, left_index=True, right_index=True)
joined_df
# Out:
#                      mcc_average  balanced_accuracy_average  f1_average  \
# split       dataset
# partitioned B           0.002015                   0.501239    0.288501
# random      B          -0.003643                   0.497552    0.246979
#
#                      AUPRC_average  precision_average  recall_average  \
# split       dataset
# partitioned B                 -1.0           0.202281        0.503195
# random      B                 -1.0           0.164495        0.495438
#
#                       mcc_std  balanced_accuracy_std    f1_std  AUPRC_std  \
# split       dataset
# partitioned B        0.010420               0.006498  0.009259        0.0
# random      B        0.008983               0.006036  0.005479        0.0
#
#                      precision_std  recall_std
# split       dataset
# partitioned B             0.008179    0.009130
# random      B             0.003387    0.014124

# %%
metrics_order = ["mcc", "f1", "precision", "recall", "AUPRC", "balanced_accuracy"]
cols = []
for m in metrics_order:
    cols.append(f"{m}_average")
    cols.append(f"{m}_std")
    
joined_df = joined_df[cols]
joined_df
# Out:
#                      mcc_average   mcc_std  f1_average    f1_std  \
# split       dataset
# partitioned B           0.002015  0.010420    0.288501  0.009259
# random      B          -0.003643  0.008983    0.246979  0.005479
#
#                      precision_average  precision_std  recall_average  \
# split       dataset
# partitioned B                 0.202281       0.008179        0.503195
# random      B                 0.164495       0.003387        0.495438
#
#                      recall_std  AUPRC_average  AUPRC_std  \
# split       dataset
# partitioned B          0.009130           -1.0        0.0
# random      B          0.014124           -1.0        0.0
#
#                      balanced_accuracy_average  balanced_accuracy_std
# split       dataset
# partitioned B                         0.501239               0.006498
# random      B                         0.497552               0.006036

# %%
drugs_df = pd.read_csv("../processed_data/drug_fingerprints.csv", index_col=0)
long_table = pd.read_csv("../processed_data/DRIAMS_combined_long_table.csv")
long_table = long_table[long_table["drug"].isin(drugs_df.index)]

long_table
# Out:
#                            species                                  sample_id  \
# 0       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# 1       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# 2       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# 3       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# 4       Staphylococcus epidermidis       e9adf43d-679b-497c-9849-1fa214838dd3
# ...                            ...                                        ...
# 652766       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
# 652767       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
# 652768       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
# 652769       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
# 652770       Staphylococcus aureus  08bc8410-51ec-46d7-ac7b-afba9e6ba2cd_3313
#
#                  drug  response dataset
# 0           Meropenem         1       A
# 1       Ciprofloxacin         1       A
# 2            Cefepime         1       A
# 3       Cotrimoxazole         0       A
# 4            Imipenem         1       A
# ...               ...       ...     ...
# 652766      Linezolid         0       D
# 652767     Rifampicin         0       D
# 652768   Tetracycline         0       D
# 652769    Tigecycline         0       D
# 652770     Vancomycin         0       D
#
# [652608 rows x 5 columns]

# %%
# folder_template = "outputs/ResAMR_DrugZeroShot/ZS_noCNN_emb512_DRIAMS-{}_drugs_zero_shot_sp0"
drug_zs_results = []
threshold = 0.5
# folder_template = "outputs/Species1hot_ResAMR/OneHot_noCNN_emb512_DRIAMS-{}_drugs_zero_shot_sp0_results"

folder = join("outputs/RandomClassifier", template.format("drugs_zero_shot"))




for fname in os.listdir(folder):
    if not fname.startswith("test"):
        continue

    drug_name = fname.split("_")[-1].split(".")[0]
    with open(join(folder, fname), "r") as f:
        metrics = json.load(f) 


    metrics["dataset"] = dataset
    metrics["drug"]= drug_name
    drug_zs_results.append(metrics)







drug_zs_results = pd.DataFrame(drug_zs_results)
# drug_zs_results.columns = ["dataset", "drug", "test_AUPRC", "n_test_samples", "n_resistant_test_samples"]
# drug_zs_results = drug_zs_results.drop("drug", axis=1)

drug_zs_results
# Out:
#          mcc  balanced_accuracy        f1  AUPRC  precision    recall dataset  \
# 0  -0.015829           0.491842  0.424754     -1   0.371007  0.496711       B
# 1   0.000000           0.495622  0.000000     -1   0.000000  0.000000       B
# 2  -0.005029           0.496565  0.237443     -1   0.157385  0.483271       B
# 3   0.170542           0.643678  0.250000     -1   0.153846  0.666667       B
# 4   0.037749           0.524630  0.285192     -1   0.193069  0.545455       B
# 5   0.049592           0.609426  0.035503     -1   0.018182  0.750000       B
# 6  -0.009301           0.478654  0.021459     -1   0.010989  0.454545       B
# 7   0.045487           0.522770  0.529583     -1   0.549296  0.511236       B
# 8   0.028467           0.516640  0.332689     -1   0.252199  0.488636       B
# 9  -0.023617           0.477685  0.121127     -1   0.069579  0.467391       B
# 10 -0.046292           0.246597  0.000000     -1   0.000000  0.000000       B
# 11 -0.007070           0.495506  0.275229     -1   0.188206  0.511945       B
# 12 -0.037685           0.247214  0.000000     -1   0.000000  0.000000       B
# 13  0.025819           0.556114  0.032000     -1   0.016438  0.600000       B
# 14  0.004032           0.502019  0.511628     -1   0.531722  0.492997       B
# 15  0.036508           0.522639  0.310867     -1   0.218992  0.535545       B
# 16 -0.004972           0.496676  0.246388     -1   0.165984  0.477876       B
# 17  0.029421           0.517058  0.348315     -1   0.259414  0.529915       B
# 18  0.019922           0.530128  0.059289     -1   0.031250  0.576923       B
# 19 -0.039024           0.437420  0.035000     -1   0.018421  0.350000       B
# 20  0.028925           0.562397  0.033241     -1   0.017094  0.600000       B
# 21  0.020555           0.518332  0.156560     -1   0.091731  0.533835       B
# 22  0.043967           0.586965  0.041763     -1   0.021531  0.692308       B
# 23 -0.026859           0.478238  0.164029     -1   0.098276  0.495652       B
# 24 -0.024218           0.486100  0.321755     -1   0.243767  0.473118       B
# 25 -0.009485           0.492483  0.178439     -1   0.109091  0.489796       B
# 26 -0.041956           0.476949  0.348367     -1   0.273839  0.478632       B
# 27 -0.033633           0.473417  0.166667     -1   0.102128  0.452830       B
# 28  0.000000           0.000000  0.000000     -1   0.000000  0.000000       B
# 29  0.015555           0.510510  0.254130     -1   0.169492  0.507614       B
# 30  0.015962           0.511214  0.234862     -1   0.154217  0.492308       B
# 31 -0.006445           0.496741  0.531602     -1   0.571695  0.496764       B
# 32  0.001336           0.500883  0.260274     -1   0.172727  0.527778       B
#
#                 drug
# 0         Cefuroxime
# 1          Linezolid
# 2           Cefepime
# 3      Metronidazole
# 4        Norfloxacin
# 5         Vancomycin
# 6          Meropenem
# 7     Nitrofurantoin
# 8       Fusidic acid
# 9           Imipenem
# 10       Tigecycline
# 11        Fosfomycin
# 12        Daptomycin
# 13       Teicoplanin
# 14        Ampicillin
# 15       Clindamycin
# 16     Ciprofloxacin
# 17      Erythromycin
# 18          Amikacin
# 19         Ertapenem
# 20         Mupirocin
# 21        Gentamicin
# 22        Rifampicin
# 23       Ceftriaxone
# 24         Oxacillin
# 25      Cotrimoxazol
# 26         Cefoxitin
# 27       Ceftazidime
# 28       Minocycline
# 29      Levofloxacin
# 30      Tetracycline
# 31  Benzylpenicillin
# 32    Clarithromycin

# %%
mean_df = drug_zs_results.groupby("dataset").mean()
mean_df.columns = [c+"_average" for c in mean_df.columns]
std_df = drug_zs_results.groupby("dataset").std()
std_df.columns = [c+"_std" for c in std_df.columns]
std_df
zs_joined_df = pd.merge(mean_df, std_df, left_index=True, right_index=True)
zs_joined_df.columns = [ c for c in zs_joined_df.columns]
zs_joined_df
metrics_order = ["mcc", "f1", "precision", "recall", "AUPRC", "balanced_accuracy"]
cols = []
for m in metrics_order:
    cols.append(f"{m}_average")
    cols.append(f"{m}_std")
    
zs_joined_df = zs_joined_df[cols]
zs_joined_df.insert(0, "split", "drugs_zero_shot")#reset_index()
zs_joined_df
# mean_df
# Out:
# <ipython-input-19-63d3a96dac04>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_df = drug_zs_results.groupby("dataset").mean()
# <ipython-input-19-63d3a96dac04>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   std_df = drug_zs_results.groupby("dataset").std()
#                    split  mcc_average   mcc_std  f1_average    f1_std  \
# dataset
# B        drugs_zero_shot     0.007346  0.040097    0.204489  0.161926
#
#          precision_average  precision_std  recall_average  recall_std  \
# dataset
# B                 0.158532       0.159286        0.459992    0.188498
#
#          AUPRC_average  AUPRC_std  balanced_accuracy_average  \
# dataset
# B                 -1.0        0.0                   0.481913
#
#          balanced_accuracy_std
# dataset
# B                     0.115272

# %%
results_df = pd.concat((joined_df.reset_index(), zs_joined_df.reset_index())).set_index(["split", "dataset"])
results_df = results_df[cols]
results_df
# Out:
#                          mcc_average   mcc_std  f1_average    f1_std  \
# split           dataset
# partitioned     B           0.002015  0.010420    0.288501  0.009259
# random          B          -0.003643  0.008983    0.246979  0.005479
# drugs_zero_shot B           0.007346  0.040097    0.204489  0.161926
#
#                          precision_average  precision_std  recall_average  \
# split           dataset
# partitioned     B                 0.202281       0.008179        0.503195
# random          B                 0.164495       0.003387        0.495438
# drugs_zero_shot B                 0.158532       0.159286        0.459992
#
#                          recall_std  AUPRC_average  AUPRC_std  \
# split           dataset
# partitioned     B          0.009130           -1.0        0.0
# random          B          0.014124           -1.0        0.0
# drugs_zero_shot B          0.188498           -1.0        0.0
#
#                          balanced_accuracy_average  balanced_accuracy_std
# split           dataset
# partitioned     B                         0.501239               0.006498
# random          B                         0.497552               0.006036
# drugs_zero_shot B                         0.481913               0.115272

# %%
results_df.to_csv("outputs/aggregate_resuts/RandomClassifier_DRIAMS-B_metrics.csv")

# %%
metrics = ["AUPRC", "balanced_accuracy", "mcc"]

for i, row in results_df.iterrows():
    
    print(i)
    for m in metrics:
        print("{:.2f} ({:.2f}) ".format(row[f"{m}_average"], row[f"{m}_std"]), end="")
        if m!="mcc":
            print(" & ", end="")
    print(" \\\ ")
# Out:
# ('partitioned', 'B')
# -1.00 (0.00)  & 0.50 (0.01)  & 0.00 (0.01)  \\
# ('random', 'B')
# -1.00 (0.00)  & 0.50 (0.01)  & -0.00 (0.01)  \\
# ('drugs_zero_shot', 'B')
# -1.00 (0.00)  & 0.48 (0.12)  & 0.01 (0.04)  \\
